# %% [markdown]
# C
# 5 6 7 8 9
#
# 5 5 11 -> 2
#
# 5 4 11 -> 3
#
# 5 3 11 -> 4
# 11作るのに最低必要なのが2つ。（←最小のものから選んでいっていくつで11以上になるか。）
# 最低2つの日本酒を引くには？
# ３つまでだと水2,酒1になる可能性あり。→４つ必要。
# →水の数＋必要数
#
#
# 18

# %% [markdown]
# E
# 10
#   ACBBCABCAB
#
# A 1    2  3
# B   12  3  4
# d 1 0- 0- 0-
#
# A +    +  +
# B   --  -  -
