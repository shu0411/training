# %% [markdown]
# A B  X Y
# 7 13 9 4
#
# A8回で(4,4)　７＊８ = 56
# あとX方向に5移動する
# 9:  X A 7
# 10: Y A 7→X A 7→Y A 7　or　X B 13　→X B 13の方が安い。
# →奇数回目はA、偶数回目はBで移動
# 7 * 3 + 13 * 2 = 47
#
# A B  X Y
# 7 13 4 9
#
# A8回で(4,4)　７＊８ = 56
# あとY方向に5移動する
# 9:  X A 7→Y A 7→X A 7　or　Y B 13　→Y B 13の方が安い。
# 10: Y A 7
# →奇数回目はB、偶数回目はAで移動
# 13 * 3 + 7 * 2 = 47
