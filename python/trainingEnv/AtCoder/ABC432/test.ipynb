# %% [markdown]
# C
# ありうる最大は、最小戸数が全部大の時。

# %% [markdown]
# E
# l以下の個数
# r以上の個数
# lより大、rより小の数の合計（orそれぞれの個数）
#
# 元の数の、
#     種類ごとの個数
#     特定の数字以下の合計
#
# 減った数字の種類ごとの個数
# 増えた数字の種類ごとの個数
#
#
# l以下を出すときに必要：l以下の数字の個数
# r以上を出すときに必要：r以上の数字の個数
# lより大、rより小の数の合計を出すときに必要：
#     それぞれの数の合計
