# %% [markdown]
# C
# 10 2 6
#  aabbccaabb
#  o     1    3-2
#   o    23   4-2
#    o     4  3-2
#     o    56 4-2
#      o      2-2
# a1222223444
# b0012222234
# c0000122222

# %% [markdown]
# D
#
# 頂点：含まれれば＋１
#
# 軸上：軸ごとに偶数の数を数える
# -1 4 →0,2,4  2
# -2 3 →-2,0,2 3
# -2 2 →-2,0,2 3
# -1 3 →0 2
#
# それ以外：すべて第1象限で考えればOK。
