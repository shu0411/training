# %%
import numpy as np
i = 1

out = np.array([["."*(3**i)]])
out_2 = np.repeat(out, 3, axis=1)
out_3 = np.repeat(out_2, 3, axis=1)
print(out)
print(out_2)
print(list(out_3))
# Out:
# [['...']]
# [['...' '...' '...']]
# [array(['...', '...', '...', '...', '...', '...', '...', '...', '...'],
#       dtype='<U3')]

# %%
import numpy as np
i = 1

out = np.array([["#"]*3,["#",".","#"],["#"]*3])
out_2 = np.array([["."]*3]*3)
out_3 = np.block([[out, out,out],[out,out_2,out],[out,out,out]])
out_4 = np.array([["."]*9]*9)
out_5 = np.block([[out_3, out_3,out_3],[out_3,out_4,out_3],[out_3,out_3,out_3]])
#out_3 = np.repeat(out, 3, axis=1)
print(out)
#print(out_2)
#print(out_3)
#print(out_4)
print(out_5)
# Out:
# [['#' '#' '#']
#  ['#' '.' '#']
#  ['#' '#' '#']]
# [['#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#'
#   '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#'
#   '#' '.' '#' '#' '.' '#' '#' '.' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#'
#   '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' '#' '#' '.' '.' '.' '#' '#' '#' '#' '#' '#' '.' '.' '.' '#' '#' '#'
#   '#' '#' '#' '.' '.' '.' '#' '#' '#']
#  ['#' '.' '#' '.' '.' '.' '#' '.' '#' '#' '.' '#' '.' '.' '.' '#' '.' '#'
#   '#' '.' '#' '.' '.' '.' '#' '.' '#']
#  ['#' '#' '#' '.' '.' '.' '#' '#' '#' '#' '#' '#' '.' '.' '.' '#' '#' '#'
#   '#' '#' '#' '.' '.' '.' '#' '#' '#']
#  ['#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#' '#'
#   '#' '#' '#' '#' '#' '#' '#' '#' '#']
#  ['#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#' '#' '.' '#'
#   '#' '.' '#' '#' '.' '#' '#' '.' '#']
# ...
