# %% [markdown]
# E
# 4 x
# 1 1 4
# 1 2 4+4
# 1 3 4+4+4
# 2 1 3+3+3
# 1 2 3+4+3
# 2 1 3+4+3
# 2 2 2+3+2
# 1 1 4+3+2
#
# Rが来た時に増える数：
# 　以前にRが出たことがないとき＝N
# 　以前にRが出たことがあるとき＝前回のRから出たCの種類
# Cが来た時に減る数：
# 　以前にCが出たことがないとき＝今までに出たRの数
# 　以前にCが出たことがあるとき＝前回のCから出たRの種類
