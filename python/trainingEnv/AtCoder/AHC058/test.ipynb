# %% [markdown]
# 3のPが 1 増える
# 2のBが P3j 増える
# 1のBが P3j * P2j 増える
# 0のBが P3j * P2j * P1j 増える
# リンゴは Aj * P3j * P2j * P1j * P0j * ターン数 増える
#
# 1のPが 1 増える
# 0のBが P1j 増える
# リンゴは Aj * P1j * P0j * ターン数 増える
#
# 0のPが+1
# 0のBはふえない。
# リンゴはAj * ターン数 増える
