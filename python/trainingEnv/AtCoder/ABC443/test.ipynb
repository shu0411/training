# %% [markdown]
# D
# 9
# 9 9 8 2 4 4 3 5 3
# 5 4 3 2 3 4 3 4 3
# 4 5 5   1     1
#
# 7 4 6 2 15 5 17 15 1 8 18 1 5 1 12 11 2 7 8 14
# 5 4 5
# 5 4 3 2 3  4 5  6
# 5 4 3 2 3  4 3  2  1 2 3
# 5 4 3 2 3  4 3  2  1 2 2  1 2 1 2  3  2 3 4 5
#
# 7 4 6 2 15 5 17 15 1 8 18 1 5 1 12 11 2 7 8 14
#         5  4 3  2  1
# 5 4 3 2 3  4 3  2  1
# 5 4 3 2 3  4 3  2  1 2 3
# 5 4 3 2 3  4 3  2  1 2 2  1 2 1 2  3  2 3 4 5

# %% [markdown]
# E
#
# ##.##.##.#
# .####..#..
# ...#.#..#.
# .#.#.#.#..
# ...####...
# #.#.##....
# .##...#...
# #.##.....#
# #....###.#
# .#..#.#...
#
# 011
# 101111????
# 01111?????
# ?111??????
# ??1???????
#
# 壁壊せる列
# 0011000010
#
# 0011010010
#
# 下から順に、そこに到達可能かをチェック。
# 到達可能な条件：
# ①自分の点より-1,0,+1が1
# ②以下のいずれか。
# 　・自分自身が空きマスじゃない
# 　・自分自身が壁壊せる列
