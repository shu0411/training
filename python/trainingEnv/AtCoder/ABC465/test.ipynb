# %% [markdown]
# E
#
# 54321
# 5→1~50000
# 4→50001~54000
# 3→54001~54300
# 2

# %% [markdown]
# C
# 1 2 3 4 5
# 2 1 3 4 5
# 3 1 2 4 5
# 4 2 1 3 5
# 5 3 1 2 4
#
# 5 3 1 2 4 6
# 6 4 2 1 3 5 7
# 7 5 3 1 2 4 6
#
#
# 1 2 3 4 5 6 7
# 7 6 5 4 3 2 1
# →k+1 - i
#
# 2
# 2+1-2
# 3+1-1
# 4+1-3
# 5+1-2 5+1-(4+1-(3+1-(2+1-2)))=5-4+3-2+2=4
# 5+1-(4+1-(3+1-3))=5-4+3+(1)-3
